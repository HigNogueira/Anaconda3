# %%
#O COEFICIENTE DE PEARSON SERVE PARA QUANTIFICAR ALGUMA CORRELAÇÃO PARA VERFIICAR SE EXISTE CORRELAÇÃO ENTRE AS DUAS.
# QUANDO O VALOR FOR PROXIMO DE 0 NAO DEVEMOS DESCARTA OUTRA ABORDAGENS . -1 0 E 1.
#TEM QUE HAVER VALORES LINEARES.

import pandas as pd
import numpy as np

from pandas import Series, DataFrame
from matplotlib import pyplot as plt
from matplotlib import rcParams

import seaborn as sns

# %%
np.random.seed(25)
indice = ['linha 1', 'linha2','linha 3', 'linha 4','linha 5']
colunas = [ 'coluna 1', 'coluna 2', 'coluna 3', 'coluna 4','coluna 5']

df = DataFrame(np.random.rand(50).reshape((5,5)),
                index=indice,
                columns=colunas)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-86ab5a984614> in <module>
#       3 colunas = [ 'coluna 1', 'coluna 2', 'coluna 3', 'coluna 4','coluna 5']
#       4
# ----> 5 df = DataFrame(np.random.rand(50).reshape((5,5)),
#       6                 index=indice,
#       7                 columns=colunas)
#
# ValueError: cannot reshape array of size 50 into shape (5,5)

# %%
sns.pairplot(df)
# PARA PUXAR UM DATAFRAME E UTILIZAR PARA ANLISE DE COEFICIENTE DE PEARSON, É NECESSARIO
